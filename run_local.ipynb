# %%
# !python main_mu_ts_8.py
# Out:
# Model: "TRX"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(256, 4, 16, 16, 2) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(256, 1)]           0
# __________________________________________________________________________________________________
# ada_se__res_net_class_d (AdaSE_ (256, 4, 16, 16, 64) 119362      input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d (MaxPooling3D)    (256, 4, 16, 16, 64) 0           ada_se__res_net_class_d[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# !python main_mu_ts_10.py
# Out:
# ada_se__res_net_class_rf_19 (Ad (256, 16, 16, 64)    83010       ada_se__res_net_class_rf_18[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_d_31 (Ada (256, 4, 16, 16, 64) 230466      ada_se__res_net_class_d_30[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_rf_8 (Ada (256, 16, 16, 64)    83010       ada_se__res_net_class_rf_7[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose (Conv3DTranspo (256, 4, 16, 16, 64) 4160        ada_se__res_net_class_d_19[0][0]
# ...

# %%
# !python main_mu_ts_12.py
# Out:
# __________________________________________________________________________________________________
# ada_se__res_net_class_d_25 (Ada (256, 4, 16, 16, 64) 230466      ada_se__res_net_class_d_24[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_rf_2 (Ada (256, 16, 16, 64)    83010       ada_se__res_net_class_rf_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_d_14 (Ada (256, 4, 16, 16, 64) 230466      ada_se__res_net_class_d_13[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# !python main_mu_ts_14.py
# Out:
# Model: "TRX"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(256, 4, 16, 16, 2) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(256, 1)]           0
# __________________________________________________________________________________________________
# ada_se__res_net_class_d (AdaSE_ (256, 4, 16, 16, 64) 119362      input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d (MaxPooling3D)    (256, 4, 16, 16, 64) 0           ada_se__res_net_class_d[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# !python main_mu_ts_16.py
# Out:
# Model: "TRX"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(256, 4, 16, 16, 2) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(256, 1)]           0
# __________________________________________________________________________________________________
# ada_se__res_net_class_d (AdaSE_ (256, 4, 16, 16, 64) 119362      input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d (MaxPooling3D)    (256, 4, 16, 16, 64) 0           ada_se__res_net_class_d[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# !python main_mu_ts_18.py
# Out:
# Model: "TRX"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(256, 4, 16, 16, 2) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(256, 1)]           0
# __________________________________________________________________________________________________
# ada_se__res_net_class_d (AdaSE_ (256, 4, 16, 16, 64) 119362      input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d (MaxPooling3D)    (256, 4, 16, 16, 64) 0           ada_se__res_net_class_d[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# !python main_mu_ts_20.py
# Out:
# proposed beamformer is evaluated
# Model: "TRX"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(256, 4, 16, 16, 2) 0
# 2022-12-29 22:18:39.414458: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-29 22:18:39.415393: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# ...

# %%
# !python main_mu_ts_22.py
# Out:
# 2022-12-29 22:33:08.829101: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-29 22:33:08.830336: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# C:\Users\jabba\miniconda3\envs\tf-env\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:3703: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable.debug_mode()`.
#   warnings.warn(
# ...

# %%
# !python main_mu_ts_24.py
# Out:
# __________________________________________________________________________________________________
# conv3d_transpose_3 (Conv3DTrans (256, 4, 16, 16, 64) 4160        ada_se__res_net_class_d_32[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_rf_10 (Ad (256, 16, 16, 64)    83010       conv2d_transpose[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (256, 4, 16, 1, 64)  0           conv3d_transpose_1[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_rf_22 (Ad (256, 16, 16, 64)    83010       conv2d_transpose_2[0][0]
#                                                                  input_2[0][0]
# ...

# %%
# !python main_mu_ts_26.py
# Out:
# ada_se__res_net_class_d_12 (Ada (256, 4, 16, 16, 64) 230466      ada_se__res_net_class_d_11[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_rf_12 (Ad (256, 16, 16, 64)    83010       reshape_7[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_d_24 (Ada (256, 4, 16, 16, 64) 230466      ada_se__res_net_class_d_23[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_rf_1 (Ada (256, 16, 16, 64)    83010       ada_se__res_net_class_rf[0][0]
# ...

# %%
# !python main_mu_ts_28.py
# Out:
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_d_7 (AdaS (256, 4, 16, 16, 64) 230466      ada_se__res_net_class_d_6[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_d_8 (AdaS (256, 4, 16, 16, 64) 230466      ada_se__res_net_class_d_7[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_d_9 (AdaS (256, 4, 16, 16, 64) 230466      ada_se__res_net_class_d_8[0][0]
#                                                                  input_2[0][0]
# ...

# %%
# !python main_mu_ts_30.py
# Out:
# ada_se__res_net_class_rf_4 (Ada (256, 16, 16, 64)    83010       ada_se__res_net_class_rf_3[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_d_16 (Ada (256, 4, 16, 16, 64) 230466      ada_se__res_net_class_d_15[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_rf_16 (Ad (256, 16, 16, 64)    83010       ada_se__res_net_class_rf_15[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# ada_se__res_net_class_d_28 (Ada (256, 4, 16, 16, 64) 230466      ada_se__res_net_class_d_27[0][0]
# ...
